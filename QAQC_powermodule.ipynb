# %%
import numpy as np
from seat.power_module import calculate_power

# %%
# lowerx=[]
# device = pd.datafarame({lower_left=})
# np.nanmin([lowerx, device.lower_left[0]-360])

# %%
calculate_power(power_files=r"C:\Users\tnelson76\OneDrive - Integral Consulting Inc\C1308 Sandia\DEMO Files\DEMO structured\power_files\4x4",
                bc_file=r"C:\Users\tnelson76\OneDrive - Integral Consulting Inc\C1308 Sandia\DEMO Files\DEMO structured\boundary-condition\boundary-conditions.csv",
                save_path=r"H:\Projects\C1308_SEAT\SEAT_outputs\Power_Test3",
                crs=4326)
# Out:
# h:\Projects\C1308_SEAT\Integral_GIT\seat-qgis-plugin\seat\power_module.py:396: RuntimeWarning: divide by zero encountered in log10
#   np.log10(Power_Scaled[:, ic]), width=1, edgecolor='black')
# h:\Projects\C1308_SEAT\Integral_GIT\seat-qgis-plugin\seat\power_module.py:413: RuntimeWarning: divide by zero encountered in log10
#   0])+1, np.log10(np.sum(Power_Scaled, axis=1)), width=1, edgecolor='black')
